# %%
import random
import csv

import os

if not os.path.exists("MOOD_HISTORY.csv"):
    with open("MOOD_HISTORY.csv", "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow([
            "Employee Code",
            "Employee Name",
            "Category",
            "Selected Mood",
            "Date",
            "Time"
        ])

print("=" * 50)
print("          MOOD TRACKER")
print("=" * 50)

print("😊 Welcome to Mood Tracker!")
print("🌟 Have a great day!")
print("💙 Stay positive!")
print("\n")

# employees giving inputs
emp_code = input("Enter Employee Code: ").upper()
password = input("Enter Password: ")

login_success = False

with open("/content/employees_500_indian_names_1.csv", mode="r", newline="", encoding="utf-8") as file:
    reader = csv.DictReader(file)

    for row in reader:
        if row["Employee Code"] == emp_code and row["Password"] == password:
            login_success = True
            employee_name = row["Employee Name"]
            break

if login_success:
    print("\n✅ Login Successful!")
    print(f"Welcome, {employee_name}")

else:
    print("\n❌ Invalid Employee Code or Password.")

print("\n")

#choose a mood from the list below.
print("Please choose a mood from the following list:")

print("1. Happy")
print("2. Sad")
print("3. Angry")
print("4. Fearful")
print("5. Confident")
print("6. Calm")
print("7. Thinking")
print("8. Social")
print("9. Confused")
print("10. Negative")
print("11. Positive")
choice = input("Enter your choice (1-11): ")

# list of moods and their corresponding traits
happy= [
    "I'm happy", "I'm joyful", "I'm excited", "I'm grateful",
    "I'm content", "I'm peaceful", "I'm optimistic",
    "I'm inspired", "I'm cheerful","I'm fine"]

sad= [
    "I'm sad", "I'm lonely", "I'm hopeless", "I'm depressed",
    "I'm disappointed", "I'm miserable", "I'm heartbroken",
    "I'm ashamed", "I'm guilty", "I'm nostalgic", "I'm relieved"]

angry= [
    "I'm angry", "I'm frustrated", "I'm furious",
    "I'm resentful", "I'm irritated", "I'm annoyed"]

fear = [
    "I'm scared", "I'm nervous", "I'm anxious",
    "I'm worried", "I'm insecure"]

confidence = [
    "I'm confident", "I'm determined", "I'm ambitious",
    "I'm resilient", "I'm motivated", "I'm focused"]

calm= [
    "I'm relaxed", "I'm patient", "I'm adaptable",
    "I'm flexible"]

thinking= [
    "I'm curious", "I'm logical", "I'm rational",
    "I'm analytical", "I'm intuitive", "I'm practical",
    "I'm creative", "I'm imaginative", "I'm artistic"]

social = [
    "I'm social", "I'm empathetic", "I'm compassionate",
    "I'm generous", "I'm helpful", "I'm respectful",
    "I'm trustworthy", "I'm loyal", "I'm responsible",
    "I'm polite"]

confused = [
    "I'm confused", "I'm uncertain", "I'm indecisive",
    "I'm distracted"]

negative = [
    "I'm selfish", "I'm dishonest", "I'm disrespectful",
    "I'm untrustworthy", "I'm disloyal", "I'm irresponsible",
    "I'm rude", "I'm impolite", "I'm unmotivated",
    "I'm undisciplined", "I'm unorganized", "I'm impatient",
    "I'm pessimistic"]

positive = [
    "I'm disciplined", "I'm organized", "I'm patient", "I'm motivated",
    "I'm ambitious", "I'm determined", "I'm focused", "I'm resilient",
    "I'm empathetic", "I'm compassionate", "I'm generous", "I'm honest",
    "I'm trustworthy", "I'm respectful", "I'm kind", "I'm polite"]

# list of quotes for each mood

happy_quotes = [
    "Happiness depends upon ourselves. — Aristotle",
    "The purpose of our lives is to be happy. — Dalai Lama",
    "The most wasted of days is one without laughter. — E. E. Cummings",
    "Count your age by friends, not years. — John Lennon",
    "Happiness is not by chance, but by choice. — Jim Rohn"
]
sad_quotes = [
    "The greatest glory in living lies not in never falling, but in rising every time we fall. — Nelson Mandela",
    "Turn your wounds into wisdom. — Oprah Winfrey",
    "Rock bottom became the solid foundation on which I rebuilt my life. — J. K. Rowling",
    "Out of difficulties grow miracles. — Jean de La Bruyère",
    "Every adversity carries with it the seed of an equal or greater benefit. — Napoleon Hill"
]
angry_quotes = [
    "For every minute you remain angry, you give up sixty seconds of peace of mind. — Ralph Waldo Emerson",
    "The best fighter is never angry. — Lao Tzu",
    "Speak when you are angry and you will make the best speech you will ever regret. — Ambrose Bierce",
    "Holding on to anger is like drinking poison. — Often attributed to Buddha",
    "Anger dwells only in the bosom of fools. — Albert Einstein"
]
fear_quotes = [
    "Do one thing every day that scares you. — Eleanor Roosevelt",
    "Believe you can and you're halfway there. — Theodore Roosevelt",
    "You have power over your mind—not outside events. — Marcus Aurelius",
    "Courage is resistance to fear, mastery of fear—not absence of fear. — Mark Twain",
    "Nothing diminishes anxiety faster than action. — Walter Anderson"
]
confidence_quotes = [
    "Whether you think you can or think you can't, you're right. — Henry Ford",
    "With confidence, you have won before you have started. — Marcus Garvey",
    "Believe in yourself and all that you are. — Christian D. Larson",
    "Act as if what you do makes a difference. It does. — William James",
    "Optimism is the faith that leads to achievement. — Helen Keller"
]
calm_quotes = [
    "Peace begins with a smile. — Mother Teresa",
    "Nothing can bring you peace but yourself. — Ralph Waldo Emerson",
    "When you realize nothing is lacking, the whole world belongs to you. — Lao Tzu",
    "The life of inner peace is harmonious and without stress. — Norman Vincent Peale",
    "Calm mind brings inner strength and self-confidence. — Dalai Lama"
]
thinking_quotes = [
    "The important thing is not to stop questioning. — Albert Einstein",
    "Knowing yourself is the beginning of all wisdom. — Aristotle",
    "Judge a man by his questions rather than by his answers. — Voltaire",
    "The mind is everything. What you think you become. — Buddha",
    "Logic will get you from A to B. Imagination will take you everywhere. — Albert Einstein"
]
social_quotes = [
    "No act of kindness, no matter how small, is ever wasted. — Aesop",
    "Kindness is a language which the deaf can hear and the blind can see. — Mark Twain",
    "We rise by lifting others. — Robert Ingersoll",
    "The best way to find yourself is to lose yourself in the service of others. — Mahatma Gandhi",
    "Wherever there is a human being, there is an opportunity for kindness. — Seneca"
]
confused_quotes = [
    "In the middle of difficulty lies opportunity. — Albert Einstein",
    "The journey of a thousand miles begins with one step. — Lao Tzu",
    "Patience is not simply the ability to wait. — Leo Tolstoy",
    "It does not matter how slowly you go as long as you do not stop. — Confucius",
    "Sometimes questions are more important than answers. — Nancy Willard"
]
negative_quotes = [
    "The greatest mistake you can make in life is to be continually fearing you will make one. — Elbert Hubbard",
    "Knowing yourself is the beginning of all wisdom. — Aristotle",
    "Every saint has a past, and every sinner has a future. — Oscar Wilde",
    "We cannot change the cards we are dealt, just how we play the hand. — Randy Pausch",
    "The only real mistake is the one from which we learn nothing. — Henry Ford",
    "Our greatest glory is not in never falling, but in rising every time we fall. — Confucius",
    "Mistakes are proof that you are trying. — Jennifer Lim",
    "The first step toward change is awareness. The second step is acceptance. — Nathaniel Branden",
    "What lies behind us and what lies before us are tiny matters compared to what lies within us. — Ralph Waldo Emerson",
    "You must be the change you wish to see in the world. — Mahatma Gandhi"
]

positive_quotes = [
    "Success is the sum of small efforts, repeated day in and day out. — Robert Collier",
    "Quality is not an act, it is a habit. — Aristotle",
    "The future depends on what you do today. — Mahatma Gandhi",
    "Character is much easier kept than recovered. — Thomas Paine",
    "Honesty is the first chapter in the book of wisdom. — Thomas Jefferson",
    "The best way to find yourself is to lose yourself in the service of others. — Mahatma Gandhi",
    "Do the right thing. It will gratify some people and astonish the rest. — Mark Twain",
    "Discipline is the bridge between goals and accomplishment. — Jim Rohn",
    "Success is nothing more than a few simple disciplines, practiced every day. — Jim Rohn",
    "Kindness is a language which the deaf can hear and the blind can see. — Mark Twain"
]
# list of health tips
health = [
    "Drink at least 8 glasses of water today.",
    "Eat a healthy breakfast every morning.",
    "Take a 10-minute walk.",
    "Get at least 7-8 hours of sleep tonight.",
    "Eat one serving of fresh fruit today.",
    "Include vegetables in every meal.",
    "Stretch your body for 5 minutes.",
    "Take deep breaths for one minute.",
    "Avoid skipping meals.",
    "Choose whole grains over refined grains.",
    "Limit sugary drinks today.",
    "Reduce your salt intake.",
    "Practice good posture while sitting.",
    "Take the stairs instead of the elevator.",
    "Wash your hands regularly.",
    "Avoid excessive junk food.",
    "Eat slowly and mindfully.",
    "Smile more often.",
    "Spend 15 minutes in the sunlight.",
    "Take regular breaks from your screen.",
    "Avoid using your phone before bedtime.",
    "Read a book for 20 minutes.",
    "Practice gratitude today.",
    "Meditate for 10 minutes.",
    "Avoid overeating.",
    "Choose healthy snacks like nuts or fruits.",
    "Drink water before each meal.",
    "Eat more fiber-rich foods.",
    "Limit processed foods.",
    "Avoid smoking.",
    "Limit alcohol consumption.",
    "Go for a short evening walk.",
    "Do 20 squats today.",
    "Try 10 push-ups if you can.",
    "Practice yoga for 15 minutes.",
    "Listen to relaxing music.",
    "Laugh at least once today.",
    "Call a friend or family member.",
    "Take care of your mental health.",
    "Write down your thoughts in a journal.",
    "Take a few minutes to relax.",
    "Keep your room clean and organized.",
    "Maintain good personal hygiene.",
    "Brush your teeth twice a day.",
    "Floss your teeth daily.",
    "Wear sunscreen when outdoors.",
    "Stay hydrated during exercise.",
    "Avoid sitting continuously for more than an hour.",
    "Stand up and stretch every hour.",
    "Practice positive self-talk.",
    "Take a break when feeling stressed.",
    "Cook a healthy meal at home.",
    "Eat more protein-rich foods.",
    "Choose healthy fats like nuts and seeds.",
    "Avoid excessive caffeine.",
    "Drink herbal tea instead of sugary drinks.",
    "Practice mindful eating.",
    "Keep healthy snacks nearby.",
    "Spend time in nature.",
    "Take a relaxing bath.",
    "Sleep and wake up at the same time daily.",
    "Keep your bedroom cool and quiet.",
    "Reduce stress through breathing exercises.",
    "Practice forgiveness.",
    "Take time to enjoy your hobbies.",
    "Exercise for at least 30 minutes.",
    "Walk after dinner.",
    "Avoid eating late at night.",
    "Drink fresh coconut water if available.",
    "Eat colorful fruits and vegetables.",
    "Avoid excessive screen time.",
    "Rest your eyes using the 20-20-20 rule.",
    "Wear comfortable footwear.",
    "Keep your workspace tidy.",
    "Set realistic daily goals.",
    "Celebrate small achievements.",
    "Spend quality time with loved ones.",
    "Practice kindness every day.",
    "Avoid comparing yourself to others.",
    "Learn something new today.",
    "Listen to your body's needs.",
    "Take medicines only as prescribed.",
    "Keep emergency contacts handy.",
    "Maintain a healthy body weight.",
    "Avoid stress eating.",
    "Practice balance exercises.",
    "Keep yourself motivated.",
    "Take care of your skin.",
    "Replace negative thoughts with positive ones.",
    "Stay physically active throughout the day.",
    "Drink clean and safe water.",
    "Avoid consuming too much sugar.",
    "Include legumes in your diet.",
    "Take a few minutes to appreciate nature.",
    "Spend time away from social media.",
    "Practice patience with yourself.",
    "Take deep breaths before reacting in anger.",
    "Remember to relax your shoulders.",
    "Believe in your ability to improve every day.",
    "Health is your greatest wealth—take care of it."]

# list of random facts
facts = [
    "Octopuses have three hearts.",
    "FHoney never spoils.",
    "Bananas are berries, but strawberries aren't.",
    "Fact 4: A day on Venus is longer than a year on Venus.",
    "Fact 5: Sharks existed before trees.",
    "Fact 6: Wombat poop is cube-shaped.",
    "Fact 7: The Eiffel Tower grows taller in summer.",
    "Fact 8: Butterflies taste with their feet.",
    "Fact 9: Cats have fewer toes on their back paws.",
    "Fact 10: Koalas sleep up to 20 hours a day.",
    "Fact 11: An ostrich's eye is bigger than its brain.",
    "Fact 12: The shortest war lasted 38 minutes.",
    "Fact 13: A group of flamingos is called a flamboyance.",
    "Fact 14: Sea otters hold hands while sleeping.",
    "Fact 15: There are more stars than grains of sand on Earth.",
    "Fact 16: The human nose can detect over 1 trillion scents.",
    "Fact 17: A cloud can weigh over a million pounds.",
    "Fact 18: Cows have best friends.",
    "Fact 19: The inventor of the Frisbee became a Frisbee.",
    "Fact 20: Hot water can freeze faster than cold water.",
    "Fact 21: Octopuses have three hearts.",
    "Fact 22: Honey never spoils.",
    "Fact 23: Bananas are berries, but strawberries aren't.",
    "Fact 24: A day on Venus is longer than a year on Venus.",
    "Fact 25: Sharks existed before trees.",
    "Fact 26: Wombat poop is cube-shaped.",
    "Fact 27: The Eiffel Tower grows taller in summer.",
    "Fact 28: Butterflies taste with their feet.",
    "Fact 29: Cats have fewer toes on their back paws.",
    "Fact 30: Koalas sleep up to 20 hours a day.",
    "Fact 31: An ostrich's eye is bigger than its brain.",
    "Fact 32: The shortest war lasted 38 minutes.",
    "Fact 33: A group of flamingos is called a flamboyance.",
    "Fact 34: Sea otters hold hands while sleeping.",
    "Fact 35: There are more stars than grains of sand on Earth.",
    "Fact 36: The human nose can detect over 1 trillion scents.",
    "Fact 37: A cloud can weigh over a million pounds.",
    "Fact 38: Cows have best friends.",
    "Fact 39: The inventor of the Frisbee became a Frisbee.",
    "Fact 40: Hot water can freeze faster than cold water.",
    "Fact 41: Octopuses have three hearts.",
    "Fact 42: Honey never spoils.",
    "Fact 43: Bananas are berries, but strawberries aren't.",
    "Fact 44: A day on Venus is longer than a year on Venus.",
    "Fact 45: Sharks existed before trees.",
    "Fact 46: Wombat poop is cube-shaped.",
    "Fact 47: The Eiffel Tower grows taller in summer.",
    "Fact 48: Butterflies taste with their feet.",
    "Fact 49: Cats have fewer toes on their back paws.",
    "Fact 50: Koalas sleep up to 20 hours a day.",
    "Fact 51: An ostrich's eye is bigger than its brain.",
    "Fact 52: The shortest war lasted 38 minutes.",
    "Fact 53: A group of flamingos is called a flamboyance.",
    "Fact 54: Sea otters hold hands while sleeping.",
    "Fact 55: There are more stars than grains of sand on Earth.",
    "Fact 56: The human nose can detect over 1 trillion scents.",
    "Fact 57: A cloud can weigh over a million pounds.",
    "Fact 58: Cows have best friends.",
    "Fact 59: The inventor of the Frisbee became a Frisbee.",
    "Fact 60: Hot water can freeze faster than cold water.",
    "Fact 61: Octopuses have three hearts.",
    "Fact 62: Honey never spoils.",
    "Fact 63: Bananas are berries, but strawberries aren't.",
    "Fact 64: A day on Venus is longer than a year on Venus.",
    "Fact 65: Sharks existed before trees.",
    "Fact 66: Wombat poop is cube-shaped.",
    "Fact 67: The Eiffel Tower grows taller in summer.",
    "Fact 68: Butterflies taste with their feet.",
    "Fact 69: Cats have fewer toes on their back paws.",
    "Fact 70: Koalas sleep up to 20 hours a day.",
    "Fact 71: An ostrich's eye is bigger than its brain.",
    "Fact 72: The shortest war lasted 38 minutes.",
    "Fact 73: A group of flamingos is called a flamboyance.",
    "Fact 74: Sea otters hold hands while sleeping.",
    "Fact 75: There are more stars than grains of sand on Earth.",
    "Fact 76: The human nose can detect over 1 trillion scents.",
    "Fact 77: A cloud can weigh over a million pounds.",
    "Fact 78: Cows have best friends.",
    "Fact 79: The inventor of the Frisbee became a Frisbee.",
    "Fact 80: Hot water can freeze faster than cold water.",
    "Fact 81: Octopuses have three hearts.",
    "Fact 82: Honey never spoils.",
    "Fact 83: Bananas are berries, but strawberries aren't.",
    "Fact 84: A day on Venus is longer than a year on Venus.",
    "Fact 85: Sharks existed before trees.",
    "Fact 86: Wombat poop is cube-shaped.",
    "Fact 87: The Eiffel Tower grows taller in summer.",
    "Fact 88: Butterflies taste with their feet.",
    "Fact 89: Cats have fewer toes on their back paws.",
    "Fact 90: Koalas sleep up to 20 hours a day.",
    "Fact 91: An ostrich's eye is bigger than its brain.",
    "Fact 92: The shortest war lasted 38 minutes.",
    "Fact 93: A group of flamingos is called a flamboyance.",
    "Fact 94: Sea otters hold hands while sleeping.",
    "Fact 95: There are more stars than grains of sand on Earth.",
    "Fact 96: The human nose can detect over 1 trillion scents.",
    "Fact 97: A cloud can weigh over a million pounds.",
    "Fact 98: Cows have best friends.",
    "Fact 99: The inventor of the Frisbee became a Frisbee.",
    "Fact 100: Hot water can freeze faster than cold water.",
    "Fact 101: Octopuses have three hearts.",
    "Fact 102: Honey never spoils.",
    "Fact 103: Bananas are berries, but strawberries aren't.",
    "Fact 104: A day on Venus is longer than a year on Venus.",
    "Fact 105: Sharks existed before trees.",
    "Fact 106: Wombat poop is cube-shaped.",
    "Fact 107: The Eiffel Tower grows taller in summer.",
    "Fact 108: Butterflies taste with their feet.",
    "Fact 109: Cats have fewer toes on their back paws.",
    "Fact 110: Koalas sleep up to 20 hours a day.",
    "Fact 111: An ostrich's eye is bigger than its brain.",
    "Fact 112: The shortest war lasted 38 minutes.",
    "Fact 113: A group of flamingos is called a flamboyance.",
    "Fact 114: Sea otters hold hands while sleeping.",
    "Fact 115: There are more stars than grains of sand on Earth.",
    "Fact 116: The human nose can detect over 1 trillion scents.",
    "Fact 117: A cloud can weigh over a million pounds.",
    "Fact 118: Cows have best friends.",
    "Fact 119: The inventor of the Frisbee became a Frisbee.",
    "Fact 120: Hot water can freeze faster than cold water.",
    "Fact 121: Octopuses have three hearts.",
    "Fact 122: Honey never spoils.",
    "Fact 123: Bananas are berries, but strawberries aren't.",
    "Fact 124: A day on Venus is longer than a year on Venus.",
    "Fact 125: Sharks existed before trees.",
    "Fact 126: Wombat poop is cube-shaped.",
    "Fact 127: The Eiffel Tower grows taller in summer.",
    "Fact 128: Butterflies taste with their feet.",
    "Fact 129: Cats have fewer toes on their back paws.",
    "Fact 130: Koalas sleep up to 20 hours a day.",
    "Fact 131: An ostrich's eye is bigger than its brain.",
    "Fact 132: The shortest war lasted 38 minutes.",
    "Fact 133: A group of flamingos is called a flamboyance.",
    "Fact 134: Sea otters hold hands while sleeping.",
    "Fact 135: There are more stars than grains of sand on Earth.",
    "Fact 136: The human nose can detect over 1 trillion scents.",
    "Fact 137: A cloud can weigh over a million pounds.",
    "Fact 138: Cows have best friends.",
    "Fact 139: The inventor of the Frisbee became a Frisbee.",
    "Fact 140: Hot water can freeze faster than cold water.",
    "Fact 141: Octopuses have three hearts.",
    "Fact 142: Honey never spoils.",
    "Fact 143: Bananas are berries, but strawberries aren't.",
    "Fact 144: A day on Venus is longer than a year on Venus.",
    "Fact 145: Sharks existed before trees.",
    "Fact 146: Wombat poop is cube-shaped.",
    "Fact 147: The Eiffel Tower grows taller in summer.",
    "Fact 148: Butterflies taste with their feet.",
    "Fact 149: Cats have fewer toes on their back paws.",
    "Fact 150: Koalas sleep up to 20 hours a day.",
    "Fact 151: An ostrich's eye is bigger than its brain.",
    "Fact 152: The shortest war lasted 38 minutes.",
    "Fact 153: A group of flamingos is called a flamboyance.",
    "Fact 154: Sea otters hold hands while sleeping.",
    "Fact 155: There are more stars than grains of sand on Earth.",
    "Fact 156: The human nose can detect over 1 trillion scents.",
    "Fact 157: A cloud can weigh over a million pounds.",
    "Fact 158: Cows have best friends.",
    "Fact 159: The inventor of the Frisbee became a Frisbee.",
    "Fact 160: Hot water can freeze faster than cold water.",
    "Fact 161: Octopuses have three hearts.",
    "Fact 162: Honey never spoils.",
    "Fact 163: Bananas are berries, but strawberries aren't.",
    "Fact 164: A day on Venus is longer than a year on Venus.",
    "Fact 165: Sharks existed before trees.",
    "Fact 166: Wombat poop is cube-shaped.",
    "Fact 167: The Eiffel Tower grows taller in summer.",
    "Fact 168: Butterflies taste with their feet.",
    "Fact 169: Cats have fewer toes on their back paws.",
    "Fact 170: Koalas sleep up to 20 hours a day.",
    "Fact 171: An ostrich's eye is bigger than its brain.",
    "Fact 172: The shortest war lasted 38 minutes.",
    "Fact 173: A group of flamingos is called a flamboyance.",
    "Fact 174: Sea otters hold hands while sleeping.",
    "Fact 175: There are more stars than grains of sand on Earth.",
    "Fact 176: The human nose can detect over 1 trillion scents.",
    "Fact 177: A cloud can weigh over a million pounds.",
    "Fact 178: Cows have best friends.",
    "Fact 179: The inventor of the Frisbee became a Frisbee.",
    "Fact 180: Hot water can freeze faster than cold water.",
    "Fact 181: Octopuses have three hearts.",
    "Fact 182: Honey never spoils.",
    "Fact 183: Bananas are berries, but strawberries aren't.",
    "Fact 184: A day on Venus is longer than a year on Venus.",
    "Fact 185: Sharks existed before trees.",
    "Fact 186: Wombat poop is cube-shaped.",
    "Fact 187: The Eiffel Tower grows taller in summer.",
    "Fact 188: Butterflies taste with their feet.",
    "Fact 189: Cats have fewer toes on their back paws.",
    "Fact 190: Koalas sleep up to 20 hours a day.",
    "Fact 191: An ostrich's eye is bigger than its brain.",
    "Fact 192: The shortest war lasted 38 minutes.",
    "Fact 193: A group of flamingos is called a flamboyance.",
    "Fact 194: Sea otters hold hands while sleeping.",
    "Fact 195: There are more stars than grains of sand on Earth.",
    "Fact 196: The human nose can detect over 1 trillion scents.",
    "Fact 197: A cloud can weigh over a million pounds.",
    "Fact 198: Cows have best friends.",
    "Fact 199: The inventor of the Frisbee became a Frisbee.",
    "Fact 200: Hot water can freeze faster than cold water.",
    "Fact 201: Octopuses have three hearts.",
    "Fact 202: Honey never spoils.",
    "Fact 203: Bananas are berries, but strawberries aren't.",
    "Fact 204: A day on Venus is longer than a year on Venus.",
    "Fact 205: Sharks existed before trees.",
    "Fact 206: Wombat poop is cube-shaped.",
    "Fact 207: The Eiffel Tower grows taller in summer.",
    "Fact 208: Butterflies taste with their feet.",
    "Fact 209: Cats have fewer toes on their back paws.",
    "Fact 210: Koalas sleep up to 20 hours a day.",
    "Fact 211: An ostrich's eye is bigger than its brain.",
    "Fact 212: The shortest war lasted 38 minutes.",
    "Fact 213: A group of flamingos is called a flamboyance.",
    "Fact 214: Sea otters hold hands while sleeping.",
    "Fact 215: There are more stars than grains of sand on Earth.",
    "Fact 216: The human nose can detect over 1 trillion scents.",
    "Fact 217: A cloud can weigh over a million pounds.",
    "Fact 218: Cows have best friends.",
    "Fact 219: The inventor of the Frisbee became a Frisbee.",
    "Fact 220: Hot water can freeze faster than cold water.",
    "Fact 221: Octopuses have three hearts.",
    "Fact 222: Honey never spoils.",
    "Fact 223: Bananas are berries, but strawberries aren't.",
    "Fact 224: A day on Venus is longer than a year on Venus.",
    "Fact 225: Sharks existed before trees.",
    "Fact 226: Wombat poop is cube-shaped.",
    "Fact 227: The Eiffel Tower grows taller in summer.",
    "Fact 228: Butterflies taste with their feet.",
    "Fact 229: Cats have fewer toes on their back paws.",
    "Fact 230: Koalas sleep up to 20 hours a day.",
    "Fact 231: An ostrich's eye is bigger than its brain.",
    "Fact 232: The shortest war lasted 38 minutes.",
    "Fact 233: A group of flamingos is called a flamboyance.",
    "Fact 234: Sea otters hold hands while sleeping.",
    "Fact 235: There are more stars than grains of sand on Earth.",
    "Fact 236: The human nose can detect over 1 trillion scents.",
    "Fact 237: A cloud can weigh over a million pounds.",
    "Fact 238: Cows have best friends.",
    "Fact 239: The inventor of the Frisbee became a Frisbee.",
    "Fact 240: Hot water can freeze faster than cold water.",
    "Fact 241: Octopuses have three hearts.",
    "Fact 242: Honey never spoils.",
    "Fact 243: Bananas are berries, but strawberries aren't.",
    "Fact 244: A day on Venus is longer than a year on Venus.",
    "Fact 245: Sharks existed before trees.",
    "Fact 246: Wombat poop is cube-shaped.",
    "Fact 247: The Eiffel Tower grows taller in summer.",
    "Fact 248: Butterflies taste with their feet.",
    "Fact 249: Cats have fewer toes on their back paws.",
    "Fact 250: Koalas sleep up to 20 hours a day.",
    "Fact 251: An ostrich's eye is bigger than its brain.",
    "Fact 252: The shortest war lasted 38 minutes.",
    "Fact 253: A group of flamingos is called a flamboyance.",
    "Fact 254: Sea otters hold hands while sleeping.",
    "Fact 255: There are more stars than grains of sand on Earth.",
    "Fact 256: The human nose can detect over 1 trillion scents.",
    "Fact 257: A cloud can weigh over a million pounds.",
    "Fact 258: Cows have best friends.",
    "Fact 259: The inventor of the Frisbee became a Frisbee.",
    "Fact 260: Hot water can freeze faster than cold water.",
    "Fact 261: Octopuses have three hearts.",
    "Fact 262: Honey never spoils.",
    "Fact 263: Bananas are berries, but strawberries aren't.",
    "Fact 264: A day on Venus is longer than a year on Venus.",
    "Fact 265: Sharks existed before trees.",
    "Fact 266: Wombat poop is cube-shaped.",
    "Fact 267: The Eiffel Tower grows taller in summer.",
    "Fact 268: Butterflies taste with their feet.",
    "Fact 269: Cats have fewer toes on their back paws.",
    "Fact 270: Koalas sleep up to 20 hours a day.",
    "Fact 271: An ostrich's eye is bigger than its brain.",
    "Fact 272: The shortest war lasted 38 minutes.",
    "Fact 273: A group of flamingos is called a flamboyance.",
    "Fact 274: Sea otters hold hands while sleeping.",
    "Fact 275: There are more stars than grains of sand on Earth.",
    "Fact 276: The human nose can detect over 1 trillion scents.",
    "Fact 277: A cloud can weigh over a million pounds.",
    "Fact 278: Cows have best friends.",
    "Fact 279: The inventor of the Frisbee became a Frisbee.",
    "Fact 280: Hot water can freeze faster than cold water.",
    "Fact 281: Octopuses have three hearts.",
    "Fact 282: Honey never spoils.",
    "Fact 283: Bananas are berries, but strawberries aren't.",
    "Fact 284: A day on Venus is longer than a year on Venus.",
    "Fact 285: Sharks existed before trees.",
    "Fact 286: Wombat poop is cube-shaped.",
    "Fact 287: The Eiffel Tower grows taller in summer.",
    "Fact 288: Butterflies taste with their feet.",
    "Fact 289: Cats have fewer toes on their back paws.",
    "Fact 290: Koalas sleep up to 20 hours a day.",
    "Fact 291: An ostrich's eye is bigger than its brain.",
    "Fact 292: The shortest war lasted 38 minutes.",
    "Fact 293: A group of flamingos is called a flamboyance.",
    "Fact 294: Sea otters hold hands while sleeping.",
    "Fact 295: There are more stars than grains of sand on Earth.",
    "Fact 296: The human nose can detect over 1 trillion scents.",
    "Fact 297: A cloud can weigh over a million pounds.",
    "Fact 298: Cows have best friends.",
    "Fact 299: The inventor of the Frisbee became a Frisbee.",
    "Fact 300: Hot water can freeze faster than cold water.",
    "Fact 301: Octopuses have three hearts.",
    "Fact 302: Honey never spoils.",
    "Fact 303: Bananas are berries, but strawberries aren't.",
    "Fact 304: A day on Venus is longer than a year on Venus.",
    "Fact 305: Sharks existed before trees.",
    "Fact 306: Wombat poop is cube-shaped.",
    "Fact 307: The Eiffel Tower grows taller in summer.",
    "Fact 308: Butterflies taste with their feet.",
    "Fact 309: Cats have fewer toes on their back paws.",
    "Fact 310: Koalas sleep up to 20 hours a day.",
    "Fact 311: An ostrich's eye is bigger than its brain.",
    "Fact 312: The shortest war lasted 38 minutes.",
    "Fact 313: A group of flamingos is called a flamboyance.",
    "Fact 314: Sea otters hold hands while sleeping.",
    "Fact 315: There are more stars than grains of sand on Earth.",
    "Fact 316: The human nose can detect over 1 trillion scents.",
    "Fact 317: A cloud can weigh over a million pounds.",
    "Fact 318: Cows have best friends.",
    "Fact 319: The inventor of the Frisbee became a Frisbee.",
    "Fact 320: Hot water can freeze faster than cold water.",
    "Fact 321: Octopuses have three hearts.",
    "Fact 322: Honey never spoils.",
    "Fact 323: Bananas are berries, but strawberries aren't.",
    "Fact 324: A day on Venus is longer than a year on Venus.",
    "Fact 325: Sharks existed before trees.",
    "Fact 326: Wombat poop is cube-shaped.",
    "Fact 327: The Eiffel Tower grows taller in summer.",
    "Fact 328: Butterflies taste with their feet.",
    "Fact 329: Cats have fewer toes on their back paws.",
    "Fact 330: Koalas sleep up to 20 hours a day.",
    "Fact 331: An ostrich's eye is bigger than its brain.",
    "Fact 332: The shortest war lasted 38 minutes.",
    "Fact 333: A group of flamingos is called a flamboyance.",
    "Fact 334: Sea otters hold hands while sleeping.",
    "Fact 335: There are more stars than grains of sand on Earth.",
    "Fact 336: The human nose can detect over 1 trillion scents.",
    "Fact 337: A cloud can weigh over a million pounds.",
    "Fact 338: Cows have best friends.",
    "Fact 339: The inventor of the Frisbee became a Frisbee.",
    "Fact 340: Hot water can freeze faster than cold water.",
    "Fact 341: Octopuses have three hearts.",
    "Fact 342: Honey never spoils.",
    "Fact 343: Bananas are berries, but strawberries aren't.",
    "Fact 344: A day on Venus is longer than a year on Venus.",
    "Fact 345: Sharks existed before trees.",
    "Fact 346: Wombat poop is cube-shaped.",
    "Fact 347: The Eiffel Tower grows taller in summer.",
    "Fact 348: Butterflies taste with their feet.",
    "Fact 349: Cats have fewer toes on their back paws.",
    "Fact 350: Koalas sleep up to 20 hours a day.",
    "Fact 351: An ostrich's eye is bigger than its brain.",
    "Fact 352: The shortest war lasted 38 minutes.",
    "Fact 353: A group of flamingos is called a flamboyance.",
    "Fact 354: Sea otters hold hands while sleeping.",
    "Fact 355: There are more stars than grains of sand on Earth.",
    "Fact 356: The human nose can detect over 1 trillion scents.",
    "Fact 357: A cloud can weigh over a million pounds.",
    "Fact 358: Cows have best friends.",
    "Fact 359: The inventor of the Frisbee became a Frisbee.",
    "Fact 360: Hot water can freeze faster than cold water.",
    "Fact 361: Octopuses have three hearts.",
    "Fact 362: Honey never spoils.",
    "Fact 363: Bananas are berries, but strawberries aren't.",
    "Fact 364: A day on Venus is longer than a year on Venus.",
    "Fact 365: Sharks existed before trees.",
    "Fact 366: Wombat poop is cube-shaped.",
    "Fact 367: The Eiffel Tower grows taller in summer.",
    "Fact 368: Butterflies taste with their feet.",
    "Fact 369: Cats have fewer toes on their back paws.",
    "Fact 370: Koalas sleep up to 20 hours a day.",
    "Fact 371: An ostrich's eye is bigger than its brain.",
    "Fact 372: The shortest war lasted 38 minutes.",
    "Fact 373: A group of flamingos is called a flamboyance.",
    "Fact 374: Sea otters hold hands while sleeping.",
    "Fact 375: There are more stars than grains of sand on Earth.",
    "Fact 376: The human nose can detect over 1 trillion scents.",
    "Fact 377: A cloud can weigh over a million pounds.",
    "Fact 378: Cows have best friends.",
    "Fact 379: The inventor of the Frisbee became a Frisbee.",
    "Fact 380: Hot water can freeze faster than cold water.",
    "Fact 381: Octopuses have three hearts.",
    "Fact 382: Honey never spoils.",
    "Fact 383: Bananas are berries, but strawberries aren't.",
    "Fact 384: A day on Venus is longer than a year on Venus.",
    "Fact 385: Sharks existed before trees.",
    "Fact 386: Wombat poop is cube-shaped.",
    "Fact 387: The Eiffel Tower grows taller in summer.",
    "Fact 388: Butterflies taste with their feet.",
    "Fact 389: Cats have fewer toes on their back paws.",
    "Fact 390: Koalas sleep up to 20 hours a day.",
    "Fact 391: An ostrich's eye is bigger than its brain.",
    "Fact 392: The shortest war lasted 38 minutes.",
    "Fact 393: A group of flamingos is called a flamboyance.",
    "Fact 394: Sea otters hold hands while sleeping.",
    "Fact 395: There are more stars than grains of sand on Earth.",
    "Fact 396: The human nose can detect over 1 trillion scents.",
    "Fact 397: A cloud can weigh over a million pounds.",
    "Fact 398: Cows have best friends.",
    "Fact 399: The inventor of the Frisbee became a Frisbee.",
    "Fact 400: Hot water can freeze faster than cold water.",
    "Fact 401: Octopuses have three hearts.",
    "Fact 402: Honey never spoils.",
    "Fact 403: Bananas are berries, but strawberries aren't.",
    "Fact 404: A day on Venus is longer than a year on Venus.",
    "Fact 405: Sharks existed before trees.",
    "Fact 406: Wombat poop is cube-shaped.",
    "Fact 407: The Eiffel Tower grows taller in summer.",
    "Fact 408: Butterflies taste with their feet.",
    "Fact 409: Cats have fewer toes on their back paws.",
    "Fact 410: Koalas sleep up to 20 hours a day.",
    "Fact 411: An ostrich's eye is bigger than its brain.",
    "Fact 412: The shortest war lasted 38 minutes.",
    "Fact 413: A group of flamingos is called a flamboyance.",
    "Fact 414: Sea otters hold hands while sleeping.",
    "Fact 415: There are more stars than grains of sand on Earth.",
    "Fact 416: The human nose can detect over 1 trillion scents.",
    "Fact 417: A cloud can weigh over a million pounds.",
    "Fact 418: Cows have best friends.",
    "Fact 419: The inventor of the Frisbee became a Frisbee.",
    "Fact 420: Hot water can freeze faster than cold water.",
    "Fact 421: Octopuses have three hearts.",
    "Fact 422: Honey never spoils.",
    "Fact 423: Bananas are berries, but strawberries aren't.",
    "Fact 424: A day on Venus is longer than a year on Venus.",
    "Fact 425: Sharks existed before trees.",
    "Fact 426: Wombat poop is cube-shaped.",
    "Fact 427: The Eiffel Tower grows taller in summer.",
    "Fact 428: Butterflies taste with their feet.",
    "Fact 429: Cats have fewer toes on their back paws.",
    "Fact 430: Koalas sleep up to 20 hours a day.",
    "Fact 431: An ostrich's eye is bigger than its brain.",
    "Fact 432: The shortest war lasted 38 minutes.",
    "Fact 433: A group of flamingos is called a flamboyance.",
    "Fact 434: Sea otters hold hands while sleeping.",
    "Fact 435: There are more stars than grains of sand on Earth.",
    "Fact 436: The human nose can detect over 1 trillion scents.",
    "Fact 437: A cloud can weigh over a million pounds.",
    "Fact 438: Cows have best friends.",
    "Fact 439: The inventor of the Frisbee became a Frisbee.",
    "Fact 440: Hot water can freeze faster than cold water.",
    "Fact 441: Octopuses have three hearts.",
    "Fact 442: Honey never spoils.",
    "Fact 443: Bananas are berries, but strawberries aren't.",
    "Fact 444: A day on Venus is longer than a year on Venus.",
    "Fact 445: Sharks existed before trees.",
    "Fact 446: Wombat poop is cube-shaped.",
    "Fact 447: The Eiffel Tower grows taller in summer.",
    "Fact 448: Butterflies taste with their feet.",
    "Fact 449: Cats have fewer toes on their back paws.",
    "Fact 450: Koalas sleep up to 20 hours a day.",
    "Fact 451: An ostrich's eye is bigger than its brain.",
    "Fact 452: The shortest war lasted 38 minutes.",
    "Fact 453: A group of flamingos is called a flamboyance.",
    "Fact 454: Sea otters hold hands while sleeping.",
    "Fact 455: There are more stars than grains of sand on Earth.",
    "Fact 456: The human nose can detect over 1 trillion scents.",
    "Fact 457: A cloud can weigh over a million pounds.",
    "Fact 458: Cows have best friends.",
    "Fact 459: The inventor of the Frisbee became a Frisbee.",
    "Fact 460: Hot water can freeze faster than cold water.",
    "Fact 461: Octopuses have three hearts.",
    "Fact 462: Honey never spoils.",
    "Fact 463: Bananas are berries, but strawberries aren't.",
    "Fact 464: A day on Venus is longer than a year on Venus.",
    "Fact 465: Sharks existed before trees.",
    "Fact 466: Wombat poop is cube-shaped.",
    "Fact 467: The Eiffel Tower grows taller in summer.",
    "Fact 468: Butterflies taste with their feet.",
    "Fact 469: Cats have fewer toes on their back paws.",
    "Fact 470: Koalas sleep up to 20 hours a day.",
    "Fact 471: An ostrich's eye is bigger than its brain.",
    "Fact 472: The shortest war lasted 38 minutes.",
    "Fact 473: A group of flamingos is called a flamboyance.",
    "Fact 474: Sea otters hold hands while sleeping.",
    "Fact 475: There are more stars than grains of sand on Earth.",
    "Fact 476: The human nose can detect over 1 trillion scents.",
    "Fact 477: A cloud can weigh over a million pounds.",
    "Fact 478: Cows have best friends.",
    "Fact 479: The inventor of the Frisbee became a Frisbee.",
    "Fact 480: Hot water can freeze faster than cold water.",
    "Fact 481: Octopuses have three hearts.",
    "Fact 482: Honey never spoils.",
    "Fact 483: Bananas are berries, but strawberries aren't.",
    "Fact 484: A day on Venus is longer than a year on Venus.",
    "Fact 485: Sharks existed before trees.",
    "Fact 486: Wombat poop is cube-shaped.",
    "Fact 487: The Eiffel Tower grows taller in summer.",
    "Fact 488: Butterflies taste with their feet.",
    "Fact 489: Cats have fewer toes on their back paws.",
    "Fact 490: Koalas sleep up to 20 hours a day.",
    "Fact 491: An ostrich's eye is bigger than its brain.",
    "Fact 492: The shortest war lasted 38 minutes.",
    "Fact 493: A group of flamingos is called a flamboyance.",
    "Fact 494: Sea otters hold hands while sleeping.",
    "Fact 495: There are more stars than grains of sand on Earth.",
    "Fact 496: The human nose can detect over 1 trillion scents.",
    "Fact 497: A cloud can weigh over a million pounds.",
    "Fact 498: Cows have best friends.",
    "Fact 499: The inventor of the Frisbee became a Frisbee.",
    "Fact 500: Hot water can freeze faster than cold water.",
]

moods_traits = {
    "1": happy,
    "2": sad,
    "3": angry,
    "4": fear,
    "5": confidence,
    "6": calm,
    "7": thinking,
    "8": social,
    "9": confused,
    "10": negative,
    "11": positive
}

mood_list = moods_traits[choice]

print("\nChoose your mood:\n")

for i, mood in enumerate(mood_list, start=1):
    print(f"{i}. {mood}")

mood_choice = int(input("\nEnter mood number: "))

selected_mood = mood_list[mood_choice - 1]

print("\nYou selected:", selected_mood)

# Define mood categories mapping for CSV logging
mood_categories_map = {
    "1": "Happy",
    "2": "Sad",
    "3": "Angry",
    "4": "Fearful",
    "5": "Confident",
    "6": "Calm",
    "7": "Thinking",
    "8": "Social",
    "9": "Confused",
    "10": "Negative",
    "11": "Positive"
}

# Get the category name based on the user's initial choice
category = mood_categories_map.get(choice, "Unknown") # Default to 'Unknown' if choice is invalid

if selected_mood in happy:
    print("😊 That's wonderful! Keep smiling and spread your positivity.")
    print(random.choice(happy_quotes))
    print("\n")

elif selected_mood in sad:
    print("❤️ I'm sorry you're feeling this way.")
    print("Remember, every difficult moment is temporary.")
    print("Talk to someone you trust or do something you enjoy.")
    print(random.choice(sad_quotes))
    print("\n")
elif selected_mood in angry:
    print("😌 Take a deep breath.")
    print("Try counting to 10 or going for a short walk.")
    print(random.choice(angry_quotes))
    print("\n")

elif  selected_mood in fear:
    print("💙 It's okay to feel anxious sometimes.")
    print("Focus on one small step at a time.")
    print(random.choice(fear_quotes))
    print("\n")

elif selected_mood in confidence:
    print("💪 You sound confident and determined!")
    print("Keep working toward your goals.")
    print(random.choice(confidence_quotes))
    print("\n")

elif selected_mood in calm:
    print("🌿 You seem calm and relaxed.")
    print("Enjoy this peaceful state of mind.")
    print(random.choice(calm_quotes))
    print("\n")

elif  selected_mood in thinking:
    print("🧠 Your curiosity and creativity are valuable strengths.")
    print(random.choice(thinking_quotes))
    print("\n")

elif selected_mood in social:
    print("🤝 You have qualities that make you a great friend and teammate.")
    print(random.choice(social_quotes))
    print("\n")

elif selected_mood in confused:
    print("🤔 Feeling confused is normal.")
    print("Take a short break and think one step at a time.")
    print(random.choice(confused_quotes))
    print("\n")

elif selected_mood in negative:
    print("🌱 Everyone has qualities they can improve.")
    print("Recognizing them is the first step toward growth.")
    print(random.choice(negative_quotes))
    print("\n")

elif selected_mood in positive:
    print("⭐ Those are excellent personal qualities. Keep it up!")
    print("\n")

else:
    print("Thank you for sharing your feelings.")
    print(random.choice(positive_quotes))


print("🍎 Health Tip:")
print(random.choice(health))
print("\n")

print("\n💡 Fun Fact:")
print(random.choice(facts))

from datetime import datetime
from zoneinfo import ZoneInfo

now = datetime.now(ZoneInfo("Asia/Kolkata"))

today = now.strftime("%d-%m-%Y")
current_time = now.strftime("%I:%M:%S %p")

with open("MOOD_HISTORY.csv", "a", newline="", encoding="utf-8") as file:

    writer = csv.writer(file)
    print("emp_code =", emp_code)
    print("employee_name =", employee_name)
    print("category =", category)
    print("selected_mood =", selected_mood)
    print("today =", today)
    print("current_time =", current_time)
    print("About to save...")

    writer.writerow([
        emp_code,
        employee_name,
        category,
        selected_mood,
        today,
        current_time
    ])

print("✅ Mood saved successfully!")
# Out:
# ...
#           MOOD TRACKER
# ...
# 😊 Welcome to Mood Tracker!
# 🌟 Have a great day!
# 💙 Stay positive!
#
#
# Enter Employee Code: EMP0127
# Enter Password: EMP0127
#
# ✅ Login Successful!
# Welcome, Rahul Kumar
#
#
# Please choose a mood from the following list:
# 1. Happy
# 2. Sad
# 3. Angry
# 4. Fearful
# 5. Confident
# 6. Calm
# 7. Thinking
# 8. Social
# 9. Confused
# 10. Negative
# 11. Positive
# Enter your choice (1-11): 1
#
# Choose your mood:
#
# 1. I'm happy
# 2. I'm joyful
# 3. I'm excited
# 4. I'm grateful
# 5. I'm content
# 6. I'm peaceful
# 7. I'm optimistic
# 8. I'm inspired
# 9. I'm cheerful
# 10. I'm fine
#
# Enter mood number: 2
#
# You selected: I'm joyful
# 😊 That's wonderful! Keep smiling and spread your positivity.
# Count your age by friends, not years. — John Lennon
#
#
# 🍎 Health Tip:
# Take a few minutes to appreciate nature.
#
#
#
# 💡 Fun Fact:
# Fact 121: Octopuses have three hearts.
# emp_code = EMP0127
# employee_name = Rahul Kumar
# category = Happy
# ...

# %%
import os

print("Current folder:", os.getcwd())

print("\nFiles:")
for f in os.listdir():
    print(f)
# Out:
# Current folder: /content
#
# Files:
# .config
# sample_data
# employees_500_indian_names_1.csv
# MOOD_HISTORY.csv

# %%
import pandas as pd

df = pd.read_csv("MOOD_HISTORY.csv")
print(df)
# Out:
#   Employee Code Employee Name Category  Selected Mood        Date         Time
# 0       EMP0269   Ankit Verma      Sad     I'm lonely  04-07-2026  05:22:23 AM
# 1       EMP0275   Sweta Verma    Angry  I'm irritated  04-07-2026  05:25:52 AM
# 2       EMP0129   Priya Kumar     Calm   I'm flexible  04-07-2026  11:06:57 AM
# 3       EMP0010   Neha Sharma    Happy   I'm peaceful  04-07-2026  11:17:20 AM
# 4       EMP0127   Rahul Kumar    Happy     I'm joyful  04-07-2026  11:23:11 AM
